# %%
from objetos import BaseDatos
import pandas as pd
import matplotlib.pyplot as plt

# %%
sql = """select pais, count(idpedido) as cuenta
from pedidos
group by pais
order by 2 desc"""

# %%
bd = BaseDatos('./empresa3.db')

# %%
df = pd.read_sql(sql, bd.con)
df.head(5)
# Out:
#              pais  cuenta
# 0  Estados Unidos     123
# 1        Alemania     122
# 2          Brasil      83
# 3         Francia      76
# 4     Reino Unido      55

# %%
df = df.head(5)
plt.pie(df.cuenta, labels=df.pais)
plt.show();
